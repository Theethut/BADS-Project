# %%
# !nvidia-smi
# Out:
# Sun May 15 03:26:46 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
#!git clone https://github.com/utkarshojha/few-shot-gan-adaptation.git

# %%
# !pip install torch==1.7.0 torchvision==0.8.1 torchaudio==0.7.0
# !pip install -r /content/drive/MyDrive/FEWSHOTGAN/data/requirements.txt
# !pip install ninja
# Out:
# ...
#      |████████████████████████████████| 776.7 MB 4.4 kB/s
# ...
#      |████████████████████████████████| 12.7 MB 48.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 29.8 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.11.0+cu113
#     Uninstalling torchaudio-0.11.0+cu113:
#       Successfully uninstalled torchaudio-0.11.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !set CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# Edit generate.py image desitnation to
# f'/content/drive/MyDrive/FEWSHOTGAN/data/test_sample/sample.png',
#
#
# Edit train.py image and model destination
# f'/content/drive/MyDrive/FEWSHOTGAN/data/checkpoints',
# f'/content/drive/MyDrive/FEWSHOTGAN/data/samples',

# %%
#demo generate ffhq stylegan
#!python /content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/generate.py --ckpt_source /content/drive/MyDrive/FEWSHOTGAN/data/checkpoints/source_ffhq.pt

# %%
#process raw data
#!python /content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/prepare_data.py --out /content/drive/MyDrive/FEWSHOTGAN/data/processed_data/dota2 --size 256 /content/drive/MyDrive/FEWSHOTGAN/data/raw_data
# Out:
# Make dataset of image sizes: 256
# 111it [00:05, 20.38it/s]

# %%
# #IF USING LOCAL DISK: create necessery create storage path
# import os

# path_list = ["/content/fewshotgan", "/content/fewshotgan/data", "/content/fewshotgan/data/checkpoints", "/content/fewshotgan/data/samples"]
# for path in path_list:
#   if not os.path.exists(path):
#     os.mkdir(path)

# %% [markdown]
# Covert .pkl to .pt
# https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=af93978cce6756533b65550b98c9e67ab2335808&device=unknown&enc_url=68747470733a2f2f7261772e67697468756275736572636f6e74656e742e636f6d2f6476736368756c747a2f7374796c6567616e322d747261696e696e672f616639333937386363653637353635333362363535353062393863396536376162323333353830382f436f6e766572745f706b6c5f746f5f70742e6970796e62&logged_in=false&nwo=dvschultz%2Fstylegan2-training&path=Convert_pkl_to_pt.ipynb&platform=android&repository_id=302484204&repository_type=Repository&version=96

# %%
#basic: !python /content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/train.py --ckpt /content/drive/MyDrive/FEWSHOTGAN/data/checkpoints/source_ffhq.pt --data_path /content/drive/MyDrive/FEWSHOTGAN/data/processed_data/dota2 --exp ffhq_to_dota2
# !python /content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/train.py --ckpt /content/drive/MyDrive/FEWSHOTGAN/data/checkpoints/hands.pt --data_path /content/drive/MyDrive/FEWSHOTGAN/data/processed_data/dota2 --exp hands_to_dota2
# Out:
# save model freq: 2500
# save image freq: 2500
# n image trained from: 111
# iter: 50002
# load model: /content/drive/MyDrive/FEWSHOTGAN/data/checkpoints/hands.pt
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/train.py", line 569, in <module>
#     discriminator.load_state_dict(ckpt["d"]) #comment
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1052, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# RuntimeError: Error(s) in loading state_dict for Patch_Discriminator:
# ...

# %%
# !python /content/drive/MyDrive/FEWSHOTGAN/few-shot-gan-adaptation-main/generate.py --ckpt_source /content/drive/MyDrive/FEWSHOTGAN/data/checkpoints/church.pt

# %%
#zip all generated image and model to one file for easy download

pretrained_model_name = 'ffhq'
#!zip -r /content/fewshotgan/data/all_data_{pretrained_model_name}.zip /content/fewshotgan/data

#download that zipped file or you can manually download it
# from google.colab import files
# files.download(f"/content/fewshotgan/data/all_data_{pretrained_model_name}.zip")

# %%
#delete all created colab folders
import shutil

#shutil.rmtree('/content/fewshotgan', ignore_errors=True)

# %% [markdown]
# '''
# https://github.com/justinpinkney/awesome-pretrained-stylegan2
# -Anime portraits
# -fursona
# --painting faces
# --ukiyoe faces
#
# https://towardsdatascience.com/generating-anime-characters-with-stylegan2-6f8ae59e237b
#
# Vary iter
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# '''
